# %% [markdown]
# ## Shack Labs : Data Scientist Assignment

# %% [markdown]
# ## Part 2: Product matching
#
# Assignment Part 2
#
# Problem statement:
#
# Using ML/DL techniques, match similar products from the Flipkart dataset with the Amazon dataset. Once similar products are matched, display the retail price from FK and AMZ side by side. Explore as many techniques as possible before choosing the final technique.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Loading the Amazon and Flipkart datasets

# %%
amazon_data = pd.read_csv(r"C:\Users\Vishal\Downloads\amazon data.csv",encoding='latin-1')
amazon = amazon_data.copy()
amazon_data.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
#                                product_category_tree               pid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1  ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...  SHOEH4GRSUBJGZXE
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2F6HUZMQ6SJ
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...  PSOEH3ZYDMSYARJ5
#
#    retail_price  discounted_price  \
# 0           982               438
# 1         32143             29121
# 2           991               551
# 3           694               325
# 4           208               258
#
#                                                image  is_FK_Advantage_product  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...                    False
# 1  ["http://img6a.flixcart.com/image/sofa-bed/j/f...                    False
# 2  ["http://img5a.flixcart.com/image/shoe/7/z/z/r...                    False
# 3  ["http://img5a.flixcart.com/image/short/6/2/h/...                    False
# 4  ["http://img5a.flixcart.com/image/pet-shampoo/...                    False
#
#                                          description       product_rating  \
# 0  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...  No rating available
# 2  Key Features of AW Bellies Sandals Wedges Heel...  No rating available
# 3  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 4  Specifications of Sicons All Purpose Arnica Do...  No rating available
#
#         overall_rating         brand  \
# 0  No rating available        Alisha
# 1  No rating available  FabHomeDecor
# 2  No rating available            AW
# 3  No rating available        Alisha
# 4  No rating available        Sicons
#
#                               product_specifications
# 0  {"product_specification"=>[{"key"=>"Number of ...
# 1  {"product_specification"=>[{"key"=>"Installati...
# 2  {"product_specification"=>[{"key"=>"Ideal For"...
# 3  {"product_specification"=>[{"key"=>"Number of ...
# 4  {"product_specification"=>[{"key"=>"Pet Type",...

# %%
flipkart_data = pd.read_csv(r'C:\Users\Vishal\Downloads\flipcart data.csv',encoding='latin-1')
flipkart = flipkart_data.copy()
flipkart_data.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
#                                product_category_tree               pid  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2FF9KEDEFGF
# 1  ["Furniture >> Living Room Furniture >> Sofa B...  SBEEH3QGU7MFYJFY
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...  SHOEH4GRSUBJGZXE
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...  SRTEH2F6HUZMQ6SJ
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...  PSOEH3ZYDMSYARJ5
#
#    retail_price  discounted_price  \
# 0         999.0             379.0
# 1       32157.0           22646.0
# 2         999.0             499.0
# 3         699.0             267.0
# 4         220.0             210.0
#
#                                                image  is_FK_Advantage_product  \
# 0  ["http://img5a.flixcart.com/image/short/u/4/a/...                    False
# 1  ["http://img6a.flixcart.com/image/sofa-bed/j/f...                    False
# 2  ["http://img5a.flixcart.com/image/shoe/7/z/z/r...                    False
# 3  ["http://img5a.flixcart.com/image/short/6/2/h/...                    False
# 4  ["http://img5a.flixcart.com/image/pet-shampoo/...                    False
#
#                                          description       product_rating  \
# 0  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...  No rating available
# 2  Key Features of AW Bellies Sandals Wedges Heel...  No rating available
# 3  Key Features of Alisha Solid Women's Cycling S...  No rating available
# 4  Specifications of Sicons All Purpose Arnica Do...  No rating available
#
#         overall_rating         brand  \
# 0  No rating available        Alisha
# 1  No rating available  FabHomeDecor
# 2  No rating available            AW
# 3  No rating available        Alisha
# 4  No rating available        Sicons
#
#                               product_specifications
# 0  {"product_specification"=>[{"key"=>"Number of ...
# 1  {"product_specification"=>[{"key"=>"Installati...
# 2  {"product_specification"=>[{"key"=>"Ideal For"...
# 3  {"product_specification"=>[{"key"=>"Number of ...
# 4  {"product_specification"=>[{"key"=>"Pet Type",...

# %%
amazon_data.shape, flipkart_data.shape
# Out:
# ((20000, 15), (20000, 15))

# %% [markdown]
# ## Extracting features of interest from the datasets

# %%
amazon_data = amazon_data[['product_name','retail_price','discounted_price']]
flipkart_data = flipkart_data[['product_name','retail_price','discounted_price']]

# %%
amazon_data.head()
# Out:
#                             product_name  retail_price  discounted_price
# 0    Alisha Solid Women's Cycling Shorts           982               438
# 1    FabHomeDecor Fabric Double Sofa Bed         32143             29121
# 2                             AW Bellies           991               551
# 3    Alisha Solid Women's Cycling Shorts           694               325
# 4  Sicons All Purpose Arnica Dog Shampoo           208               258

# %%
flipkart_data.head()
# Out:
#                             product_name  retail_price  discounted_price
# 0    Alisha Solid Women's Cycling Shorts         999.0             379.0
# 1    FabHomeDecor Fabric Double Sofa Bed       32157.0           22646.0
# 2                             AW Bellies         999.0             499.0
# 3    Alisha Solid Women's Cycling Shorts         699.0             267.0
# 4  Sicons All Purpose Arnica Dog Shampoo         220.0             210.0

# %% [markdown]
# ## Sentence Transformers

# %% [markdown]
# Sentence transformers is a Python framework for cutting-edge sentence vector representations. Having the phrases in space allows us to calculate the distance between them, and by doing so, we can identify the ones that are most comparable in terms of their semantic meaning.
#
# For computing embeddings of sentences, paragraphs, and entire documents, the Sentence Transformers library is particularly effective. An embedding is just a vector representation of a text and is useful for finding how similar two texts are.

# %%
# !pip install sentence_transformers
# Out:
# Requirement already satisfied: sentence_transformers in c:\python310\lib\site-packages (2.2.2)
# Requirement already satisfied: sentencepiece in c:\python310\lib\site-packages (from sentence_transformers) (0.1.97)
# Requirement already satisfied: numpy in c:\python310\lib\site-packages (from sentence_transformers) (1.23.1)
# Requirement already satisfied: tqdm in c:\python310\lib\site-packages (from sentence_transformers) (4.64.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in c:\python310\lib\site-packages (from sentence_transformers) (0.11.1)
# Requirement already satisfied: torch>=1.6.0 in c:\python310\lib\site-packages (from sentence_transformers) (1.13.0)
# Requirement already satisfied: scipy in c:\python310\lib\site-packages (from sentence_transformers) (1.9.1)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\python310\lib\site-packages (from sentence_transformers) (4.24.0)
# Requirement already satisfied: scikit-learn in c:\python310\lib\site-packages (from sentence_transformers) (1.1.2)
# Requirement already satisfied: nltk in c:\python310\lib\site-packages (from sentence_transformers) (3.7)
# Requirement already satisfied: torchvision in c:\python310\lib\site-packages (from sentence_transformers) (0.14.0)
# Requirement already satisfied: packaging>=20.9 in c:\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (21.3)
# Requirement already satisfied: filelock in c:\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.4.0)
# Requirement already satisfied: requests in c:\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\python310\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\python310\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.2)
# Requirement already satisfied: colorama in c:\python310\lib\site-packages (from tqdm->sentence_transformers) (0.4.5)
# Requirement already satisfied: click in c:\python310\lib\site-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: joblib in c:\python310\lib\site-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\python310\lib\site-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\python310\lib\site-packages (from torchvision->sentence_transformers) (9.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\python310\lib\site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence_transformers) (3.0.9)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\python310\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\python310\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python310\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python310\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.9.24)
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install ipywidgets
# Out:
# Requirement already satisfied: ipywidgets in c:\python310\lib\site-packages (8.0.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\python310\lib\site-packages (from ipywidgets) (4.0.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\python310\lib\site-packages (from ipywidgets) (6.15.1)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\python310\lib\site-packages (from ipywidgets) (3.0.3)
# Requirement already satisfied: traitlets>=4.3.1 in c:\python310\lib\site-packages (from ipywidgets) (5.3.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\python310\lib\site-packages (from ipywidgets) (8.4.0)
# Requirement already satisfied: psutil in c:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.1)
# Requirement already satisfied: debugpy>=1.0 in c:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.2)
# Requirement already satisfied: tornado>=6.1 in c:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.3.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: nest-asyncio in c:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: packaging in c:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: pyzmq>=17 in c:\python310\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (23.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pickleshare in c:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.12.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.30)
# Requirement already satisfied: colorama in c:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.5)
# Requirement already satisfied: backcall in c:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (63.2.0)
# Requirement already satisfied: decorator in c:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: stack-data in c:\python310\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\python310\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (4.11.1)
# Requirement already satisfied: entrypoints in c:\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python310\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: wcwidth in c:\python310\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\python310\lib\site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.9)
# Requirement already satisfied: executing in c:\python310\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.9.1)
# Requirement already satisfied: pure-eval in c:\python310\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens in c:\python310\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pywin32>=1.0 in c:\python310\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (304)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer, util
import torch

# %%
#I'll be using the "all-MiniLM-L6-v2" Sentence Transformer model for calculating semantic similarity between Amazon and Flipkart product names

# %%
# Instantiate a model of the SentenceTransformer class
model = SentenceTransformer('all-MiniLM-L6-v2')

# Compute embedding for both Amazon and Flipkart product names
amazon_prod_embs = model.encode(amazon_data.product_name,convert_to_tensor=True)
flipkart_prod_embs = model.encode(flipkart_data.product_name,convert_to_tensor=True)

# Compute cosine similarities
cosine_sim_scores = util.cos_sim(amazon_prod_embs,flipkart_prod_embs)

# %%
# Storing the index of a similar Flipkart product corresponding to each Amazon product 
similar_prod_indexes = []

for i in range(20000):
    max_score_idxs = torch.topk(cosine_sim_scores[i],k=5,largest=True,sorted=True).indices
    for idx in max_score_idxs:
        if idx != i:
            similar_prod_indexes.append(idx)
            break

# %%
similar_prod_indexes = [x.item() for x in similar_prod_indexes]

# %%
amazon_data.product_name[2936], flipkart_data.product_name[similar_prod_indexes[2936]]
# Out:
# ("Folklore Festive Sleeveless Solid Women's Top",
#  "Folklore Festive Sleeveless Printed Women's Top")

# %%
# Extracting the details such as retail price and discounted price for both Flipkart and Amazon similar products
flipkart_prod_data = []
amazon_prod_data = []

for idx, prod_name in enumerate(amazon_data.product_name):
    flipkart_prod_data.append(flipkart_data.iloc[similar_prod_indexes[idx]])
    amazon_prod_data.append(amazon_data.iloc[idx])

# %%
flipkart_prod_data = pd.DataFrame(flipkart_prod_data)
flipkart_prod_data.columns = ['Product name in Flipkart','Retail Price in Flipkart','Discounted Price in Flipkart']
amazon_prod_data = pd.DataFrame(amazon_prod_data)
amazon_prod_data.columns = ['Product name in Amazon','Retail Price in Amazon','Discounted Price in Amazon']

# %%
flipkart_prod_data.head(10)
# Out:
#                                 Product name in Flipkart  \
# 3                    Alisha Solid Women's Cycling Shorts
# 16                   FabHomeDecor Fabric Double Sofa Bed
# 17691                                   i-Sports Bellies
# 0                    Alisha Solid Women's Cycling Shorts
# 20            Sicons Conditioning Conditoner Dog Shampoo
# 5251   Aaishwarya Glim Glam Crystal Crystal Alloy Nec...
# 3                    Alisha Solid Women's Cycling Shorts
# 16                   FabHomeDecor Fabric Double Sofa Bed
# 15764                         Provogue Corporate Casuals
# 3                    Alisha Solid Women's Cycling Shorts
#
#        Retail Price in Flipkart  Discounted Price in Flipkart
# 3                         699.0                         267.0
# 16                      32157.0                       22646.0
# 17691                     899.0                         399.0
# 0                         999.0                         379.0
# 20                        110.0                         100.0
# 5251                     1450.0                         599.0
# 3                         699.0                         267.0
# 16                      32157.0                       22646.0
# 15764                    2485.0                        2485.0
# 3                         699.0                         267.0

# %%
amazon_prod_data['Retail Price in Amazon'] = amazon_prod_data['Retail Price in Amazon'].astype(np.float64)
amazon_prod_data['Discounted Price in Amazon'] = amazon_prod_data['Discounted Price in Amazon'].astype(np.float64)
amazon_prod_data.head()
# Out:
#                   Product name in Amazon  Retail Price in Amazon  \
# 0    Alisha Solid Women's Cycling Shorts                   982.0
# 1    FabHomeDecor Fabric Double Sofa Bed                 32143.0
# 2                             AW Bellies                   991.0
# 3    Alisha Solid Women's Cycling Shorts                   694.0
# 4  Sicons All Purpose Arnica Dog Shampoo                   208.0
#
#    Discounted Price in Amazon
# 0                       438.0
# 1                     29121.0
# 2                       551.0
# 3                       325.0
# 4                       258.0

# %%
flipkart_prod_final_data = flipkart_prod_data.copy()
flipkart_prod_final_data = flipkart_prod_final_data.reset_index(drop=True)
flipkart_prod_final_data.head()
# Out:
#                      Product name in Flipkart  Retail Price in Flipkart  \
# 0         Alisha Solid Women's Cycling Shorts                     699.0
# 1         FabHomeDecor Fabric Double Sofa Bed                   32157.0
# 2                            i-Sports Bellies                     899.0
# 3         Alisha Solid Women's Cycling Shorts                     999.0
# 4  Sicons Conditioning Conditoner Dog Shampoo                     110.0
#
#    Discounted Price in Flipkart
# 0                         267.0
# 1                       22646.0
# 2                         399.0
# 3                         379.0
# 4                         100.0

# %%
amazon_prod_data.shape, flipkart_prod_final_data.shape
# Out:
# ((20000, 3), (20000, 3))

# %%
final_prod_data = pd.concat([flipkart_prod_final_data,amazon_prod_data],axis=1)
final_prod_data.to_csv('final_result.csv')

# %%
final_prod_data.head()
# Out:
#                      Product name in Flipkart  Retail Price in Flipkart  \
# 0         Alisha Solid Women's Cycling Shorts                     699.0
# 1         FabHomeDecor Fabric Double Sofa Bed                   32157.0
# 2                            i-Sports Bellies                     899.0
# 3         Alisha Solid Women's Cycling Shorts                     999.0
# 4  Sicons Conditioning Conditoner Dog Shampoo                     110.0
#
#    Discounted Price in Flipkart                 Product name in Amazon  \
# 0                         267.0    Alisha Solid Women's Cycling Shorts
# 1                       22646.0    FabHomeDecor Fabric Double Sofa Bed
# 2                         399.0                             AW Bellies
# 3                         379.0    Alisha Solid Women's Cycling Shorts
# 4                         100.0  Sicons All Purpose Arnica Dog Shampoo
#
#    Retail Price in Amazon  Discounted Price in Amazon
# 0                   982.0                       438.0
# 1                 32143.0                     29121.0
# 2                   991.0                       551.0
# 3                   694.0                       325.0
# 4                   208.0                       258.0
